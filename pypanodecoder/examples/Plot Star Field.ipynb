# %%
# %matplotlib inline
import sys
sys.path.append("../..")

from matplotlib import pyplot as plt
from pypanodecoder import plotting

# %%
fig = plt.figure(dpi=200)
ps = plotting.plot_star_field('mrk501',label='Mrk 501')
